# %% [markdown]
# データの永続化

# %% [markdown]
# SQLite
# ・軽量データベースを実装するC言語のライブラリ
# ・サーバ用のプロセスを必要としない，組み込み型のデータベースエンジン．
# ・単一のファイルによって管理される（インメモリも可能

# %%
import sqlite3

# %%
# DBファイルの保存先パス（相対パスで指定）
path = ''

# Google Colabの場合
# path = '/content/'

# DBファイル
db_name = 'test.db'

# DB接続の確立
# DBファイルが存在しない場合は新規作成される
conn = sqlite3.connect(path + db_name)

# DBへの接続を閉じる
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8 db_name = 'test.db'
#      10 # DB接続の確立
#      11 # DBファイルが存在しない場合は新規作成される
# ---> 12 conn = sqlite3.connect(path + db_name)
#      14 # DBへの接続を閉じる
#      15 conn.close()
#
# NameError: name 'sqlite3' is not defined
